# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl 
import os
mpl.rcParams['lines.linewidth']   = 2
mpl.rcParams['axes.linewidth']    = 2
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['ytick.major.width'] = 2
mpl.rcParams['ytick.labelsize']   = 10
mpl.rcParams['xtick.labelsize']   = 10
mpl.rcParams['axes.labelsize']    = 10
mpl.rcParams['legend.numpoints']  = 1
mpl.rcParams['axes.labelweight']  = 'semibold'
mpl.rcParams['axes.titlesize']    = 10
mpl.rcParams['axes.titleweight']  = 'semibold'
mpl.rcParams['font.weight']       = 'semibold'

# %%
import interface as thymeNL
import lcfunctions as lcfunc

# %%
from importlib import reload
reload(thymeNL)
targets = os.listdir('spoc_LCs')

for targ in targets:
    data = pd.read_csv('spoc_LCs/'+str(targ))
    t = data['time'].to_numpy(dtype = 'float')
    f = data['PDCSAP_flux'].to_numpy(dtype = 'float')
    f = f / np.median(f)
    
    tic = targ.split('_')[0]
    target_name = float(tic.split('c')[1])
    target = thymeNL.target(target_name)
    target.load_data(t,f)
    
    target.run_notch(window=0.5,mindbic=-1.0)
    data['notch'] = target.notch.bicstat
    
    data.to_csv('spoc_LCs/'+str(targ), index = False)
# Out:
#   0%|          | 0/12706 [00:00<?, ?it/s]
#   0%|          | 5/12706 [00:00<04:47, 44.24it/s]
# Running notch filter pipeline with windowsize of 0.5 and minimum DeltaBIC of -1.0
# Running Detrend
#   0%|          | 8/12706 [00:00<05:36, 37.76it/s]
#   0%|          | 12/12706 [00:00<05:38, 37.46it/s]
#   0%|          | 16/12706 [00:00<05:44, 36.84it/s]
#   0%|          | 19/12706 [00:00<06:12, 34.06it/s]
#   0%|          | 24/12706 [00:00<05:39, 37.30it/s]
#   0%|          | 29/12706 [00:00<05:18, 39.76it/s]
#   0%|          | 37/12706 [00:00<04:31, 46.62it/s]
#   0%|          | 42/12706 [00:00<04:42, 44.78it/s]
#   0%|          | 47/12706 [00:01<04:42, 44.85it/s]
#   0%|          | 53/12706 [00:01<04:28, 47.13it/s]
#   0%|          | 58/12706 [00:01<04:31, 46.54it/s]
#   0%|          | 63/12706 [00:01<04:36, 45.77it/s]
#   1%|          | 68/12706 [00:01<04:46, 44.06it/s]
#   1%|          | 73/12706 [00:01<04:40, 45.06it/s]
#   1%|          | 80/12706 [00:01<04:10, 50.41it/s]
#   1%|          | 87/12706 [00:01<03:57, 53.23it/s]
#   1%|          | 95/12706 [00:01<03:38, 57.74it/s]
#   1%|          | 102/12706 [00:02<04:20, 48.31it/s]
#   1%|          | 109/12706 [00:02<04:00, 52.43it/s]
#   1%|          | 115/12706 [00:02<04:01, 52.10it/s]
#   1%|          | 121/12706 [00:02<03:54, 53.71it/s]
#   1%|          | 128/12706 [00:02<03:39, 57.26it/s]
#   1%|          | 134/12706 [00:02<03:43, 56.19it/s]
#   1%|          | 140/12706 [00:02<03:50, 54.48it/s]
#   9%|▉         | 1152/12706 [00:24<03:38, 52.83it/s]
#   9%|▉         | 1158/12706 [00:24<03:33, 54.07it/s]
#   9%|▉         | 1164/12706 [00:24<03:35, 53.51it/s]
#   9%|▉         | 1170/12706 [00:25<03:51, 49.80it/s]
#   9%|▉         | 1176/12706 [00:25<03:53, 49.41it/s]
#   9%|▉         | 1182/12706 [00:25<03:49, 50.15it/s]
#   9%|▉         | 1188/12706 [00:25<03:38, 52.68it/s]
#   9%|▉         | 1197/12706 [00:25<03:13, 59.62it/s]
#   9%|▉         | 1205/12706 [00:25<02:58, 64.34it/s]
#  10%|▉         | 1213/12706 [00:25<02:49, 67.95it/s]
#  10%|▉         | 1221/12706 [00:25<02:54, 65.66it/s]
#  10%|▉         | 1228/12706 [00:25<03:11, 59.84it/s]
#  10%|▉         | 1235/12706 [00:26<03:31, 54.22it/s]
#  10%|▉         | 1241/12706 [00:26<03:52, 49.27it/s]
#  10%|▉         | 1247/12706 [00:26<03:59, 47.79it/s]
#  10%|▉         | 1252/12706 [00:26<04:33, 41.86it/s]
#  10%|▉         | 1258/12706 [00:26<04:10, 45.74it/s]
#  10%|▉         | 1263/12706 [00:26<04:03, 46.94it/s]
#  10%|▉         | 1268/12706 [00:26<04:08, 46.07it/s]
#  10%|█         | 1274/12706 [00:26<03:52, 49.15it/s]
#  10%|█         | 1280/12706 [00:27<03:43, 51.03it/s]
#  10%|█         | 1286/12706 [00:27<03:42, 51.23it/s]
#  10%|█         | 1292/12706 [00:27<03:47, 50.20it/s]
#  10%|█         | 1298/12706 [00:27<03:43, 51.07it/s]
#  10%|█         | 1306/12706 [00:27<03:20, 56.98it/s]
#  10%|█         | 1314/12706 [00:27<03:07, 60.69it/s]
#  10%|█         | 1321/12706 [00:27<03:16, 57.87it/s]
#  10%|█         | 1327/12706 [00:27<03:34, 53.12it/s]
#  10%|█         | 1333/12706 [00:28<03:34, 52.98it/s]
#  11%|█         | 1339/12706 [00:28<03:46, 50.19it/s]
#  11%|█         | 1345/12706 [00:28<03:47, 49.89it/s]
#  11%|█         | 1351/12706 [00:28<03:45, 50.46it/s]
#  11%|█         | 1357/12706 [00:28<03:53, 48.61it/s]
#  11%|█         | 1362/12706 [00:28<04:04, 46.48it/s]
#  11%|█         | 1368/12706 [00:28<03:53, 48.54it/s]
#  11%|█         | 1373/12706 [00:28<04:39, 40.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-681d73327b05> in <module>
#      14     target.load_data(t,f)
#      15
# ---> 16     target.run_notch(window=0.5,mindbic=-1.0)
#      17     data['notch'] = target.notch.bicstat
#      18
#
# ~/Notch_and_LOCoR/interface.py in run_notch(self, window, mindbic, useraw)
#     123
#     124
# --> 125         notch = lcfunctions.run_notch(self.data,window=window,mindbic=mindbic,useraw=useraw)
#     126         self.notch = notch.copy()
#     127         self.notch_windowsize = window*1.0
#
# ~/Notch_and_LOCoR/lcfunctions.py in run_notch(data, window, mindbic, useraw)
#      58
#      59     print('Running notch filter pipeline with windowsize of ' + str(window) + ' and minimum DeltaBIC of ' +str(mindbic))
# ---> 60     fittimes,depth,detrend,polyshape,badflag = core.do_detrend(1,1001,arclength=False,raw=useraw,wsize=window,indata=data,saveoutput=False,outdir='',resolvabletrans=False,demode=1,cleanup=True,deltabic=mindbic)
#      61
#      62     ##Store everything in a common format recarray
#
# ~/Notch_and_LOCoR/core.py in do_detrend(cnum, epic, arclength, raw, wsize, totalfilename, data_dir, outdir, saveoutput, resolvabletrans, k2sff, indata, idstring, known_period, known_period2, deltabic, cleanup, period_matching, snrcut, demode, max_period, min_period, alias_num, tess)
#    1886     ##run the detrending sliding notch fitter, LOCoR, or Something Else???!?
#    1887     print('Running Detrend')
# -> 1888     if demode == 1: fittimes, depth, detrend,polyshape,badflag = sliding_window(data,windowsize=wsize,use_arclength=arclength,use_raw=raw,deltabic=deltabic,resolvable_trans=resolvabletrans,cleanmask=transmask) ##Notch Filter
#    1889     if demode == 2: fittimes,depth,detrend,polyshape,badflag = rcomb(data,wsize,cleanmask=transmask,aliasnum=alias_num) ##LOCoR
#    1890
#
# ~/Notch_and_LOCoR/core.py in sliding_window(data, windowsize, use_arclength, use_raw, efrac, resolvable_trans, cleanmask, deltabic, animator, animatorfunc)
#     349             ##run the fit with no fixed parameters but from the best grid point result from above
#     350             pstart  = bestpars
# --> 351             pars,extrares = mpyfit.fit(transit_window_slide_pyfit,pstart,args=(wdat.t,wdat.fraw,error,wdat.s,thistime),parinfo=parinfo2,maxiter=200)
#     352             themod,modpoly,modnotch,modresid = transit_window_slide_pyfit(pars,args=(wdat.t,wdat.fraw,error,wdat.s,thistime),model=True)
#     353
#
# ~/anaconda3/lib/python3.7/site-packages/mpyfit-0.9.0-py3.7-macosx-10.7-x86_64.egg/mpyfit/__init__.py in fit(function, p, args, parinfo, ftol, xtol, gtol, epsfcn, stepfactor, covtol, maxiter, maxfev)
#     181         function, numpy.asarray(p), args=args, parinfo=parinfo, ftol=ftol,
#     182         xtol=xtol, gtol=gtol, epsfcn=epsfcn, stepfactor=stepfactor,
# --> 183         covtol=covtol, maxiter=maxiter, maxfev=maxfev)
#     184     status = {
#     185         1: 'Convergence in chi-squared value',
#
# ~/Notch_and_LOCoR/core.py in transit_window_slide_pyfit(p, args, model)
#     131
#     132
# --> 133     transitshape = notchbox(t,p[5],p[6],ttime)
#     134     themod = polyshape*transitshape
#     135     resid = (fl-themod)/sig_fl
#
# ~/Notch_and_LOCoR/core.py in notchbox(x, depth, width, middle)
#      98 ##transit like box function. Depth is a fractional depth, width is in days (as is x)
#      99 def notchbox(x,depth,width,middle):
# --> 100     tbox         = x.copy()*0.0 +1
#     101     inside       = np.where(np.absolute(x-middle) < width/2)[0]
#     102     tbox[inside] = 1.0-depth
#
# KeyboardInterrupt:
